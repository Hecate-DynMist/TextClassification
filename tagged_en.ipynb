# %%
import pandas as pd
df = pd.read_excel('eigen_en.xlsx')

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from gensim.models import Word2Vec

# %%
stop = set(stopwords.words('english'))

# %%
import re
def clean(sentence):
    snow = nltk.stem.SnowballStemmer('english')
    sentence = sentence.lower()                 # Converting to lowercase
    cleanr = re.compile('<.*?>')
    sentence = re.sub(cleanr, ' ', sentence)        #Removing HTML tags
    sentence = re.sub(r'[?|!|\'|"|#]',r'',sentence)
    sentence = re.sub(r'[.|,|)|(|\|/]',r' ',sentence)        #Removing Punctuations
    words = [snow.stem(word) for word in sentence.split() if word not in stopwords.words('english')]   # Stemming and removing stopwords
    return words

# %%
def token(df):
    df = df.reset_index(drop=True)
    df['ccontent'] = ''
    df['ctitle'] = ''
    for i in range(len(df)):
        df['ccontent'][i] = clean(df['content'][i])
        df['ctitle'][i] = clean(df['title'][i])
    return df

# %%
token(df).to_excel('eigen_en.xlsx')

# %%
df.to_excel('eigen_en.xlsx')

# %%
df
# Out:
#            id                                            content  \
# 0     1168920    We present an algorithm to determine quasist...
# 1     1168921    Objective: To develop and evaluate FastConte...
# 2     1168922    We address the problem of personalization in...
# 3     1168923    Now that machine learning algorithms lie at ...
# 4     1168924    Converting malware into images followed by v...
# 5     1168925    We introduce the Precise Synthetic Image and...
# 6     1168926    Most of the information on the Internet is r...
# 7     1168927    The widespread popularization of vehicles ha...
# 8     1168928    Competitive diving is a well recognized aqua...
# 9     1168929    In the usual deep neural network optimizatio...
# 10    1168930    The arXiv has collected 1.5 million pre-prin...
# 11    1168931    Foreground object segmentation is a critical...
# 12    1168932    In this paper, we address the problem of gen...
# 13    1168933    Subspace clustering methods based on data se...
# 14    1168934    mmWave technology is set to become a main fe...
# 15    1168935    Convolutional neural networks (CNNs) are ver...
# 16    1168936    While in recent years machine learning (ML) ...
# 17    1168937    Great performances of deep learning are unde...
# 18    1168938    In this paper, we present a cyber-physical t...
# 19    1168939    In future transportation systems, the chargi...
# 20    1168940    Behavior and motion planning play an importa...
# 21    1168941    We describe a new semantic parsing setting t...
# 22    1168942    In this work, we present the development of ...
# 23    1168943    Understanding human's language requires comp...
# 24    1168944    The MAVLink is a lightweight communication p...
# 25    1168945    In this work we describe the preparation of ...
# 26    1168946    Attribute guided face image synthesis aims t...
# 27    1168947    The cosine-based softmax losses and their va...
# 28    1168948    Virtual Human Simulation has been widely use...
# 29    1168949    Many real-world solutions for image restorat...
# ...       ...                                                ...
# 6951  1175871    We describe an end-to-end neural network wei...
# 6952  1175872    This paper addresses the problem of very lar...
# 6953  1175873    In machine learning, the cost function is cr...
# 6954  1175874    Image captioning has attracted considerable ...
# 6955  1175875    In recent years, an increasing number of neu...
# 6956  1175876    We consider the problem of two-player zero-s...
# 6957  1175877    Heuristic algorithms such as simulated annea...
# 6958  1175878    AI Ethics is now a global topic of discussio...
# 6959  1175879    In this work we examine the problematic asso...
# 6960  1175880    Retinex theory is developed mainly to decomp...
# 6961  1175881    In unsupervised learning, collecting more da...
# 6962  1175882    Learning deep generative models for 3D shape...
# 6963  1175883    The capabilities of super-resolution reconst...
# 6964  1175884    Product Quantization (PQ) has long been a ma...
# 6965  1175885    This paper mainly deals with the "black-box"...
# 6966  1175886    Deep Reinforcement Learning (DRL) has led to...
# 6967  1175887    A smoothing algorithm is presented that can ...
# 6968  1175888    Variational auto-encoder (VAE) with Gaussian...
# 6969  1175889    Vehicle routing problems have been the focus...
# 6970  1175890    This paper introduces a meta-learning approa...
# 6971  1175891    Noise suppression systems generally produce ...
# 6972  1175892    Despite the phenomenal success of deep neura...
# 6973  1175893    The vast and growing number of publications ...
# 6974  1175894    Unmanned Aerial Vehicles (UAVs) with Microwa...
# 6975  1175895    Convolutional neural networks (CNN) recently...
# 6976  1175896    SAP is the market leader in enterprise softw...
# 6977  1175897    Conebeam CT using a circular trajectory is q...
# 6978  1175898    This paper presents a convolutional neural n...
# 6979  1175899    Signatures provide a succinct description of...
# 6980  1175900    Bayesian networks are a versatile and powerf...
#
#                                                   title
# 0     3D Grasp Stability Analysis with Coulomb Frict...
# 1     FastContext: an efficient and scalable impleme...
# 2              Personalized Ranking in eCommerce Search
# 3                Fair Classification and Social Welfare
# 4     To believe or not to believe: Validating expla...
# 5     Precise Synthetic Image and LiDAR (PreSIL) Dat...
# 6     Nested Variational Autoencoder for Topic Model...
# 7     Cross Domain Knowledge Learning with Dual-bran...
# 8     Attentive Spatio-Temporal Representation Learn...
# 9                  Forget the Learning Rate, Decay Loss
# 10                     On the Use of ArXiv as a Dataset
# 11    Predicting How to Distribute Work Between Algo...
# 12    Appearance and Pose-Conditioned Human Image Ge...
# 13    Self-Supervised Convolutional Subspace Cluster...
# 14    Source Coding Based mmWave Channel Estimation ...
# 15      Harmonic Networks with Limited Training Samples
# 16    Declarative Question Answering over Knowledge ...
# 17    Unsupervised Temperature Scaling: Post-Process...
# 18    Cyber-Physical Testbed for Human-Robot Collabo...
# 19    On the Interaction between Autonomous Mobility...
# 20    Driving with Style: Inverse Reinforcement Lear...
# 21    Context-Dependent Semantic Parsing over Tempor...
# 22    A Self-Organizing Network with Varying Density...
# 23      ASER: A Large-scale Eventuality Knowledge Graph
# 24    MAVSec: Securing the MAVLink Protocol for Ardu...
# 25    Surface Type Classification for Autonomous Rob...
# 26          Learn to synthesize and synthesize to learn
# 27    AdaCos: Adaptively Scaling Cosine Logits for E...
# 28    Automatic Dataset Augmentation Using Virtual H...
# 29    Multi-level Encoder-Decoder Architectures for ...
# ...                                                 ...
# 6951  Model Compression by Entropy Penalized Reparam...
# 6952  REMAP: Multi-layer entropy-guided pooling of d...
# 6953  Mixture separability loss in a deep convolutio...
# 6954  Image Captioning with Integrated Bottom-Up and...
# 6955            A Closer Look at Double Backpropagation
# 6956  Solution of Two-Player Zero-Sum Game by Succes...
# 6957  Reinforcement Learning Driven Heuristic Optimi...
# 6958               AI Ethics -- Too Principled to Fail?
# 6959  Dealing with the database variability problem ...
# 6960  STAR: A Structure and Texture Aware Retinex Model
# 6961                          One Epoch Is All You Need
# 6962  Learning Part Generation and Assembly for Stru...
# 6963  On training deep networks for satellite image ...
# 6964  Beyond Product Quantization: Deep Progressive ...
# 6965  A General Interpretation of Deep Learning by A...
# 6966  MoËT: Interpretable and Verifiable Reinforceme...
# 6967  A tunable multiresolution smoother for scatter...
# 6968  Fixing Gaussian Mixture VAEs for Interpretable...
# 6969  A concise guide to existing and emerging vehic...
# 6970  Meta-learning Pseudo-differential Operators wi...
# 6971        Parametric Resynthesis with neural vocoders
# 6972  Finding the Needle in the Haystack with Convol...
# 6973  Predicting Research Trends with Semantic and N...
# 6974  On-board Deep Q-Network for UAV-assisted Onlin...
# 6975  Multi-scale Embedded CNN for Music Tagging (Ms...
# 6976  Machine Learning Software Engineering in Pract...
# 6977  Differentiated Backprojection Domain Deep Lear...
# 6978  Modeling Music Modality with a Key-Class Invar...
# 6979  Signatures in Shape Analysis: an Efficient App...
# 6980  From Incomplete, Dynamic Data to Bayesian Netw...
#
# [4916 rows x 3 columns]
